# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
targetUrl=['https://news.google.com/topics/CAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAE?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant','https://news.google.com/topics/CAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAE/sections/CAQiNENCQVNJUW9JTDIwdk1HdDBOVEVTQlhwb0xWUlhJZzRJQkJvS0NnZ3ZiUzh3TkhOb015Z0EqKQgAKiUICiIfQ0JBU0VRb0lMMjB2TUd0ME5URVNCWHBvTFZSWEtBQVABUAE?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant','https://news.google.com/topics/CAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAE/sections/CAQiNENCQVNJUW9JTDIwdk1HdDBOVEVTQlhwb0xWUlhJZzRJQkJvS0NnZ3ZiUzh3TkhOb015Z0EqKQgAKiUICiIfQ0JBU0VRb0lMMjB2TUd0ME5URVNCWHBvTFZSWEtBQVABUAE?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant','https://news.google.com/topics/CAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAE/sections/CAQiNkNCQVNJZ29JTDIwdk1HdDBOVEVTQlhwb0xWUlhJZzhJQkJvTENna3ZiUzh3TVcxM01uZ29BQSopCAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAFQAQ?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant','https://news.google.com/topics/CAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAE/sections/CAQiNkNCQVNJZ29JTDIwdk1HdDBOVEVTQlhwb0xWUlhJZzhJQkJvTENna3ZiUzh3TTNnMk9XY29BQSopCAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAFQAQ?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant','https://news.google.com/topics/CAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAE/sections/CAQiNENCQVNJUW9JTDIwdk1HdDBOVEVTQlhwb0xWUlhJZzRJQkJvS0NnZ3ZiUzh3TldScVl5Z0EqKQgAKiUICiIfQ0JBU0VRb0lMMjB2TUd0ME5URVNCWHBvTFZSWEtBQVABUAE?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant']
for taurl in targetUrl:

    res = urlopen(taurl)
    soup = BeautifulSoup(res, "html.parser")
    #print soup.select(".esc-body")
    oldNews=0
    oldNewslist=list()
    count = 0
    local='https://news.google.com'
    title=list()
    url=list()
    time=list()
    companyList=list()
    final=set()
    
    
    target=['肝病防治學術基金會','新藥','免疫療法','乳癌','吉利德','肝','血糖','台灣','脂肪肝','Gilead','']
    for item in soup.select(".xrnccd"):
        #print(len(soup.select(".xrnccd")))
        #print(len(item.select(".mEaVNd")))
       # print(item.select(".mEaVNd")[0].text)
        #print(len(item.select('time')))
        if len(item.select(".mEaVNd"))== len(item.select('time')):
            #print(len(item.select(".mEaVNd")))
           # print(len(item.select('time')))
            #print('Two Objects have same times')
            blockTitle=item.select(".mEaVNd")
            #print(len(blockTitle))
            if len(blockTitle)!=0:
                for index in range(len(blockTitle)):
                    if len(blockTitle[index].select('.HO8did'))!=0:
                        Newstitle=blockTitle[index].select('.HO8did')[0].text
                        for targ in target:
                            if targ in Newstitle:
                                company=item.select('.KbnJ8')[0].text
                                Newsurl=local+blockTitle[index].select('a')[0]['href'].replace('.','')
                                Newstime=item.select('time')[index].text
#                                 if '今天' in Newstime or '昨天' in Newstime or '時' in Newstime:  
#                                     url.append(Newsurl)
#                                     title.append(Newstitle+"#"+company)
#                                     time.append(Newstime)
                                url.append(Newsurl)
                                title.append(Newstitle+"#"+company)
                                time.append(Newstime)


        elif len(item.select(".mEaVNd"))==1 and len(item.select('time'))==0:
            oldNews+=1
            blockTitle=item.select(".mEaVNd")
            oldNewslist.append(blockTitle[0].select('.HO8did')[0].text)

        else:
            print('內容無法對上')
            print('請打給維修人員 Alex Chien')
if len(title)==0:
    print('沒有此類型新聞')
else:
         
    for i in range(len(time)):
        final.add(time[i]+'#'+title[i]+'#'+url[i])
#         print("第 "+str(i)+" 筆")
#         print('時間: '+time[i])
#         print('標題: '+title[i])
#         print('網址: '+url[i])
    print('筆數為:'+str(len(final))+' 筆')  
    for i2 in final:
        temp=i2.split('#')
        count+=1
        print("第 "+str(count)+" 筆")
        print('時間: '+temp[0])
        print('標題: '+temp[1])
        print('來源: '+temp[2])
        print('網址: '+temp[3])
print('===========================================================')
print('沒有日期但與關鍵字相關者為: '+str(oldNews)+' 筆')
for old in oldNewslist:
    print(old)
    print('-------------------------------------------------------')
# Out:
# 筆數為:66 筆
# 第 1 筆
# 時間: 上個月
# 標題: 毒素無所不在，只要在日常飲食中多多攝取排毒食物， 就能輕鬆強化身體排毒系統，將毒素順利排出。郵政醫院營養師黃淑惠從食物的「防禦毒素進入」與「幫助毒素清除」2功能，篩選出10大最佳排毒食物。 《詳全文...》
# 來源: ETtoday 新聞雲
# 網址: https://news.google.com/articles/CAIiELALCOBKJtbIE-EK2iYEvysqFwgEKg4IACoGCAowr7I3MKfqBzDfkoMG
# 第 2 筆
# 時間: 上個月
# 標題: 民眾都被騙了！永和豆漿是許多人早餐和宵夜的首選，充滿家鄉味的餐點常讓人一口接著一口，不小心就把高澱粉、高油脂和高熱量通通吃下肚。這回，《Taiwan Nutrition台灣營養》就公佈「永豆熱量一覽表」，最肥品項竟是看似健康、養生的紫米飯糰，逼近每餐建議攝取熱量，讓網友崩潰被騙好久，以後都不敢點了！ 《詳全文...》
# 來源: ETtoday 新聞雲
# 網址: https://news.google.com/articles/CAIiEKkcNTs_FSj2a1TsfKmyhi8qFwgEKg4IACoGCAowr7I3MKfqBzDPkoMG
# 第 3 筆
# 時間: 上個月
# ...
